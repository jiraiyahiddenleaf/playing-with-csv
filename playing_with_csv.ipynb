# %%
import pandas as pd

# %% [markdown]
# ### 1. opening a local csv file

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 2. opening csv file from URL

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# ### 3. set Parameter

# %%
# the data file type is tsv means it doesn't have ',' and also this data set doesn't have title of the column 
pd.read_csv('movie_titles_metadata.tsv',sep='\t',names=['sno','name','release_year','rating','votes','genres'])
# Out:
#       sno                        name release_year  rating     votes  \
# 0      m0  10 things i hate about you         1999     6.9   62847.0
# 1      m1  1492: conquest of paradise         1992     6.2   10421.0
# 2      m2                  15 minutes         2001     6.1   25854.0
# 3      m3       2001: a space odyssey         1968     8.4  163227.0
# 4      m4                     48 hrs.         1982     6.9   22289.0
# ..    ...                         ...          ...     ...       ...
# 612  m612                    watchmen         2009     7.8  135229.0
# 613  m613                         xxx         2002     5.6   53505.0
# 614  m614                       x-men         2000     7.4  122149.0
# 615  m615          young frankenstein         1974     8.0   57618.0
# 616  m616                   zulu dawn         1979     6.4    1911.0
#
#                                                 genres
# 0                                 ['comedy' 'romance']
# ...

# %% [markdown]
# ### 4. index_col paremeter

# %%
# its used to make any column to index
pd.read_csv('train.csv',index_col='PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### 5. Header parameter

# %%
pd.read_csv('test.csv') # sometimes the pandas convert header row to data because its named as 0th
# Out:
#    Unnamed: 0   Unnamed: 1 Unnamed: 2              Unnamed: 3 Unnamed: 4  \
# 0           0  enrollee_id       city  city_development_index     gender
# 1           1        29725    city_40                   0.776       Male
# 2           2        11561    city_21                   0.624        NaN
# 3           3        33241   city_115                   0.789        NaN
# 4           4          666   city_162                   0.767       Male
#
#                 Unnamed: 5           Unnamed: 6       Unnamed: 7  \
# 0      relevent_experience  enrolled_university  education_level
# 1   No relevent experience        no_enrollment         Graduate
# 2   No relevent experience     Full time course         Graduate
# 3   No relevent experience                  NaN         Graduate
# 4  Has relevent experience        no_enrollment          Masters
#
#          Unnamed: 8  Unnamed: 9   Unnamed: 10     Unnamed: 11   Unnamed: 12  \
# ...

# %%
pd.read_csv('test.csv', header=1)
# Out:
#    0  enrollee_id      city  city_development_index gender  \
# 0  1        29725   city_40                   0.776   Male
# 1  2        11561   city_21                   0.624    NaN
# 2  3        33241  city_115                   0.789    NaN
# 3  4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0   No relevent experience       no_enrollment        Graduate
# 1   No relevent experience    Full time course        Graduate
# 2   No relevent experience                 NaN        Graduate
# 3  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         15        50-99         Pvt Ltd           >4
# 1             STEM          5          NaN             NaN        never
# 2  Business Degree         <1          NaN         Pvt Ltd        never
# ...

# %% [markdown]
# ### 6. use cols parameter

# %%
# its used to take only wanted col from the datasets 
pd.read_csv('train.csv', usecols=['Survived', 'Pclass', 'Age', 'Embarked'])
# Out:
#      Survived  Pclass   Age Embarked
# 0           0       3  22.0        S
# 1           1       1  38.0        C
# 2           1       3  26.0        S
# 3           1       1  35.0        S
# 4           0       3  35.0        S
# ..        ...     ...   ...      ...
# 886         0       2  27.0        S
# 887         1       1  19.0        S
# 888         0       3   NaN        S
# 889         1       1  26.0        C
# 890         0       3  32.0        Q
#
# [891 rows x 4 columns]

# %% [markdown]
# ### 7. Squeeze parameters

# %%
pd.read_csv('train.csv',usecols=['Survived'],squeeze=True) # its a series not data frame
# Out:
# /var/folders/_d/kkj4npcs7fs5j848kl2rb82m0000gn/T/ipykernel_46707/3178102060.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   pd.read_csv('train.csv',usecols=['Survived'],squeeze=True) # its a series not data frame
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %% [markdown]
# ### 8. Skiprows/nrows Paramete

# %%
pd.read_csv('train.csv', skiprows=[2,3,4]) ## it will skip the rows 2,3,4
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 1              5         0       3                  Allen, Mr. William Henry
# 2              6         0       3                          Moran, Mr. James
# 3              7         0       1                   McCarthy, Mr. Timothy J
# 4              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 883          887         0       2                     Montvila, Rev. Juozas
# 884          888         1       1              Graham, Miss. Margaret Edith
# 885          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 886          890         1       1                     Behr, Mr. Karl Howell
# 887          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
pd.read_csv('train.csv', nrows=100) # number of rows
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %% [markdown]
# ### 9. Encoding parameter

# %%
pd.read_csv('zomato.csv') 
# this is showing error because of encoding so eiter change the encoding using any textediter or use the bellow command
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 pd.read_csv('zomato.csv')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
pd.read_csv('zomato.csv', encoding='latin-1').sample(4)
# Out:
#       Restaurant ID                        Restaurant Name  Country Code  \
# 340        17501308                           Martin's BBQ           216
# 7618       18263236                         Domino's Pizza             1
# 2829           6079                       Break Fast Point             1
# 7512           3910  24/7 Restaurant - The Lalit New Delhi             1
#
#            City                                            Address  \
# 340       Macon  102 S Armed Forces Boulevard, Warner Robins, G...
# 7618  New Delhi    1st Floor, Unity One Mall, Janakpuri, New Delhi
# 2829  New Delhi  27, Satnam Park, Bhagat Singh Road, Chander Na...
# 7512  New Delhi  The Lalit, Barakhamba Avenue, Barakhamba Road,...
#
#                                   Locality  \
# 340                          Warner Robins
# 7618             Unity One Mall, Janakpuri
# 2829                         Chander Nagar
# 7512  The Lalit New Delhi, Barakhamba Road
#
# ...

# %% [markdown]
# ### 10. skip bad lines

# %%
# something dataset has more values in col then below error occor
# it will show parser error 
pd.read_csv('BX-Books.csv', sep=';', encoding='latin-1')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[51], line 3
#       1 # something dataset has more values in col then below error occor
#       2 # it will show parser error
# ----> 3 pd.read_csv('BX-Books.csv', sep=';', encoding='latin-1')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
pd.read_csv('BX-Books.csv', sep=',', encoding="latin-1",error_bad_lines=False)
# Out:
# /var/folders/_d/kkj4npcs7fs5j848kl2rb82m0000gn/T/ipykernel_46707/943499446.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   pd.read_csv('BX-Books.csv', sep=',', encoding="latin-1",error_bad_lines=False)
# /var/folders/_d/kkj4npcs7fs5j848kl2rb82m0000gn/T/ipykernel_46707/943499446.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('BX-Books.csv', sep=',', encoding="latin-1",error_bad_lines=False)
#               isbn                                         book_title  \
# 0        195153448                                Classical Mythology
# 1          2005018                                       Clara Callan
# 2         60973129                               Decision in Normandy
# 3        374157065  Flu: The Story of the Great Influenza Pandemic...
# ...

# %% [markdown]
# ### 11. dtypes parameter
#     used to change data types

# %%
pd.read_csv('aug_train.csv').sample(3)
# here the target row is in float which is using more memory so we'll change this to integer
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 7808         14432   city_71                   0.884    Male
# 11826         8963  city_103                   0.920  Female
# 5644         29121   city_72                   0.795    Male
#
#            relevent_experience enrolled_university education_level  \
# 7808   Has relevent experience       no_enrollment         Masters
# 11826  Has relevent experience       no_enrollment     High School
# 5644   Has relevent experience       no_enrollment     High School
#
#       major_discipline experience company_size company_type last_new_job  \
# 7808              STEM        >20        10/49      Pvt Ltd            4
# 11826              NaN         12          NaN          NGO            2
# 5644               NaN          5    1000-4999      Pvt Ltd            1
#
#        training_hours  target
# 7808              306     0.0
# 11826              16     0.0
# 5644               49     0.0

# %%
pd.read_csv('aug_train.csv').info()
# here the target row is in float which is using more memory so we'll change this to integer
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# ...

# %%
pd.read_csv('aug_train.csv',dtype={'target':int}).info()
# now the target datatype is int64 from float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  int64
# ...

# %% [markdown]
# ### 12. handling dates
#
#     sometimes the dates are converted into string (object) so in this case we can't use the date functionality

# %%
pd.read_csv('IPL Matches 2008-2020.csv').info()
# date is in object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
pd.read_csv('IPL Matches 2008-2020.csv', parse_dates=['date']).info()
# now the date is in datetime64
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %% [markdown]
# ### 13. Convertors

# %%
pd.read_csv('IPL Matches 2008-2020.csv').sample(10)
# here team name is too big so we will rename them
# Out:
#           id       city        date  player_of_match  \
# 385   598061     Ranchi  2013-05-15        MK Pandey
# 267   548325     Mumbai  2012-04-16         S Nadeem
# 189   501212  Hyderabad  2011-04-16      PC Valthaty
# 603  1082617    Kolkata  2017-04-23  NM Coulter-Nile
# 88    392213  Centurion  2009-05-07          A Singh
# 205   501229      Kochi  2011-04-27         I Sharma
# 476   829741  Ahmedabad  2015-04-21         SE Marsh
# 262   548320    Kolkata  2012-04-13  Shakib Al Hasan
# 122   419113    Kolkata  2010-03-16         MS Dhoni
# 401   729285  Abu Dhabi  2014-04-18        AM Rahane
#
#                                          venue  neutral_venue  \
# 385         JSCA International Stadium Complex              0
# 267                           Wankhede Stadium              0
# 189  Rajiv Gandhi International Stadium, Uppal              0
# 603                               Eden Gardens              0
# 88                             SuperSport Park              1
# ...

# %%
def rename(name):
    if name == "Royal Challengers Bangalore":
        return "RCB"
    if name == "Kolkata Knight Riders":
        return "KKR"
    if name == "Rajasthan Royals":
        return "RR"
    if name == "Chennai Super Kings":
       return "CSK"
    else:
        return name
    
    # we can change all the names of the team

# %%
rename("Chennai Super Kings")
# Out:
# 'CSK'

# %%
#rename the teams 
pd.read_csv('IPL Matches 2008-2020.csv',converters={'team1':rename, 'team2':rename}).sample(5)
# Out:
#           id       city        date  player_of_match  \
# 649  1136574     Mumbai  2018-04-17        RG Sharma
# 52    336035    Kolkata  2008-05-25         Umar Gul
# 773  1216509    Sharjah  2020-10-17         S Dhawan
# 109   392234     Durban  2009-05-20   M Muralitharan
# 127   419118  Ahmedabad  2010-03-20  AA Jhunjhunwala
#
#                             venue  neutral_venue           team1  \
# 649              Wankhede Stadium              0  Mumbai Indians
# 52                   Eden Gardens              0             KKR
# 773       Sharjah Cricket Stadium              0             CSK
# 109                     Kingsmead              1             CSK
# 127  Sardar Patel Stadium, Motera              0              RR
#
#                team2                  toss_winner toss_decision  \
# 649              RCB  Royal Challengers Bangalore         field
# 52   Kings XI Punjab              Kings XI Punjab           bat
# ...

# %% [markdown]
# ### 14. na_values parameter

# %%
# somethimes data dont use NaN instead uses '-' so we have to comvert '-' to NAN 
# here we are converting male to NaN
pd.read_csv('aug_train.csv',na_values=['Male']).sample(5)
# Out:
#        enrollee_id      city  city_development_index gender  \
# 3763          9883  city_103                   0.920    NaN
# 4042         31970  city_103                   0.920    NaN
# 5103          4673   city_10                   0.895    NaN
# 14888        23872  city_103                   0.920    NaN
# 13570          986   city_64                   0.666    NaN
#
#            relevent_experience enrolled_university education_level  \
# 3763   Has relevent experience       no_enrollment        Graduate
# 4042   Has relevent experience       no_enrollment        Graduate
# 5103   Has relevent experience       no_enrollment         Masters
# 14888  Has relevent experience       no_enrollment        Graduate
# 13570  Has relevent experience       no_enrollment        Graduate
#
#       major_discipline experience company_size    company_type last_new_job  \
# 3763              STEM        >20          NaN             NaN            2
# ...

# %% [markdown]
# ### 15. Loading a huge dataset in chunks

# %% [markdown]
#  In pandas, chunks refer to a technique used when handling large datasets, where the data is divided into smaller, more manageable pieces called chunks. This helps to reduce memory usage and allows for efficient processing and iteration through the data.

# %%
dfs = pd.read_csv('aug_train.csv',chunksize=5000)

# %%
for chunks in dfs:
    print(chunks.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (5000, 14)
# (4158, 14)
